# %%
import uproot
import awkward as ak
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# events = uproot.open("/cms/user/zhangzhx/nonMD_TOP_ParT_data/nonMD_top_data/ZprimeToTT_M1200to4500_W12to45_TuneCP2_PSweights/dnnTuples_6839710-18.root") 
events1 = uproot.open("/cms/user/zhangzhx/nonMD_TOP_ParT_data/nonMD_top_data/ZprimeToTT_M1200to4500_W12to45_TuneCP2_PSweights/dnnTuples_6839710-36.root") 
events2 = uproot.open("/cms/user/zhangzhx/nonMD_TOP_ParT_data/nonMD_top_data/BulkGravToZZToZhadZhad_narrow_M-500to4500_TuneCP5_13TeV-madgraph-pythia/dnnTuples_6839711-58.root") 
events3 = uproot.open("/cms/user/zhangzhx/nonMD_TOP_ParT_data/GloParT_data/20230504_ak8_UL17_v8/QCD_Pt_170toInf_ptBinned_TuneCP5_13TeV_pythia8/dnnTuples_8065357-106.root")

# %%
events1["deepntuplizer/tree"].keys()
# Out:
# ['Delta_gen_pt',
#  'event_no',
#  'gen_pt',
#  'isB',
#  'isBB',
#  'isC',
#  'isG',
#  'isLeptonicB',
#  'isLeptonicB_C',
#  'isS',
#  'isUD',
#  'isUndefined',
#  'jet_corr_pt',
#  'jet_custom_discs',
#  'jet_eta',
#  'jet_no',
#  'jet_phi',
#  'jet_pt',
#  'jet_tightId',
#  'npv',
#  'ntrueInt',
#  'rho',
#  'fj_corrsdmass',
#  'fj_doubleb',
#  'fj_eta',
#  'fj_genOverReco_mass',
#  'fj_genOverReco_mass_null',
#  'fj_genOverReco_nomu_mass_null',
#  'fj_genOverReco_nomu_pt_null',
#  'fj_genOverReco_nomu_sdmass_null',
#  'fj_genOverReco_pt',
#  'fj_genOverReco_pt_null',
#  'fj_genOverReco_sdmass',
#  'fj_genOverReco_sdmass_null',
#  'fj_gen_deltaR',
#  'fj_gen_eta',
#  'fj_gen_mass',
#  'fj_gen_phi',
#  'fj_gen_pt',
#  'fj_gendau1_deltaR',
#  'fj_gendau1_eta',
#  'fj_gendau1_mass',
#  'fj_gendau1_phi',
#  'fj_gendau1_pt',
#  'fj_gendau2_deltaR',
#  'fj_gendau2_eta',
#  'fj_gendau2_mass',
#  'fj_gendau2_phi',
#  'fj_gendau2_pt',
#  'fj_genjet_mass',
#  'fj_genjet_nomu_mass',
# ...

# %%
events["deepntuplizer/tree"].keys()
# Out:
# ['Delta_gen_pt',
#  'event_no',
#  'gen_pt',
#  'isB',
#  'isBB',
#  'isC',
#  'isG',
#  'isLeptonicB',
#  'isLeptonicB_C',
#  'isS',
#  'isUD',
#  'isUndefined',
#  'jet_corr_pt',
#  'jet_eta',
#  'jet_no',
#  'jet_phi',
#  'jet_pt',
#  'jet_tightId',
#  'npv',
#  'ntrueInt',
#  'rho',
#  'fj_corrsdmass',
#  'fj_doubleb',
#  'fj_eta',
#  'fj_genOverReco_mass',
#  'fj_genOverReco_mass_null',
#  'fj_genOverReco_nomu_mass_null',
#  'fj_genOverReco_nomu_pt_null',
#  'fj_genOverReco_nomu_sdmass_null',
#  'fj_genOverReco_pt',
#  'fj_genOverReco_pt_null',
#  'fj_genOverReco_sdmass',
#  'fj_genOverReco_sdmass_null',
#  'fj_gen_deltaR',
#  'fj_gen_eta',
#  'fj_gen_mass',
#  'fj_gen_phi',
#  'fj_gen_pt',
#  'fj_gendau1_deltaR',
#  'fj_gendau1_eta',
#  'fj_gendau1_mass',
#  'fj_gendau1_phi',
#  'fj_gendau1_pt',
#  'fj_gendau2_deltaR',
#  'fj_gendau2_eta',
#  'fj_gendau2_mass',
#  'fj_gendau2_phi',
#  'fj_gendau2_pt',
#  'fj_genjet_mass',
#  'fj_genjet_nomu_mass',
#  'fj_genjet_nomu_pt',
# ...

# %%
plt.hist(events1["deepntuplizer/tree"]['jet_pt'].arrays()['jet_pt']);
